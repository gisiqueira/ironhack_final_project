# %%
import pandas as pd
import numpy as np

# %%
nome  = pd.read_csv('dataset/all_nominees/IMDb movies.csv')
nome
# Out:
# C:\Users\gisiq\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# ...

# %%
nome.keys()
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
nome.year.unique()
# Out:
# array([1894, 1906, 1911, 1912, 1919, 1913, 1914, 1915, 1916, 1917, 1918,
#        1920, 1921, 1924, 1922, 1923, 1925, 1926, 1935, 1927, 1928, 1983,
#        1929, 1930, 1932, 1931, 1937, 1938, 1933, 1934, 1936, 1940, 1939,
#        1942, 1943, 1941, 1948, 1944, 2001, 1946, 1945, 1947, 1973, 1949,
#        1950, 1952, 1951, 1962, 1953, 1954, 1955, 1961, 1956, 1958, 1957,
#        1959, 1960, 1963, 1965, 1971, 1964, 1966, 1968, 1967, 1969, 1976,
#        1970, 1979, 1972, 1981, 1978, 2000, 1989, 1975, 1974, 1986, 1990,
#        2018, 1977, 1982, 1980, 1993, 1984, 1985, 1988, 1987, 2005, 1991,
#        2002, 1994, 1992, 1995, 2017, 1997, 1996, 2006, 1999, 1998, 2007,
#        2008, 2003, 2004, 2010, 2009, 2011, 2013, 2012, 2016, 2015, 2014,
#        2019, 2020, '2012', '2015', '2009', '2013', '2018', '2014', '2017',
#        '2011', '2016', '1981', '1975', '2010', '1984', '2007', '2006',
#        '2001', '2004', '1979', '2019', '1967', '1978', '2003', '2005',
# ...

# %%
recente  = pd.read_csv('recente2.csv')
recente
# Out:
#    imdb_title_id                  title_pt
# 0      tt1825683        Infiltrado na Klan
# 1      tt7349662             Pantera Negra
# 2      tt1727824         Bohemian Rhapsody
# 3      tt5083738                A Favorita
# 4      tt6966692        Green Book: O Guia
# 5      tt1517451         Nasce Uma Estrela
# 6      tt6266538                      Vice
# 7      tt1950186           Ford v. Ferrari
# 8      tt1302006                O Irlandes
# 9      tt2584384               Jojo Rabbit
# 10     tt7286456                   Coringa
# 11     tt3281548        Adoraveis Mulheres
# 12     tt7653254  História de um Casamento
# 13     tt8579674                      1917
# 14     tt7131622  Era uma vez em Hollywood
# 15     tt6751668                  Parasita

# %%
nominated = pd.merge(recente, nome, on="imdb_title_id")
nominated
# Out:
#    imdb_title_id                  title_pt                           title  \
# 0      tt1825683        Infiltrado na Klan                   Black Panther
# 1      tt7349662             Pantera Negra                  BlacKkKlansman
# 2      tt1727824         Bohemian Rhapsody               Bohemian Rhapsody
# 3      tt5083738                A Favorita                     La favorita
# 4      tt6966692        Green Book: O Guia                      Green Book
# 5      tt1517451         Nasce Uma Estrela                  A Star Is Born
# 6      tt6266538                      Vice        Vice - L'uomo nell'ombra
# 7      tt1950186           Ford v. Ferrari   Le Mans '66 - La grande sfida
# 8      tt1302006                O Irlandes                    The Irishman
# 9      tt2584384               Jojo Rabbit                     Jojo Rabbit
# 10     tt7286456                   Coringa                           Joker
# ...

# %%
nominated8 = nominated[['imdb_title_id', 'title', 'title_pt', 'year', 'avg_vote', 'votes', 'metascore', 'duration', 'genre', 'director', 'actors',  'writer', 'budget','usa_gross_income', 'worlwide_gross_income', 'description']]

# %%
nominated8
# Out:
#    imdb_title_id                           title                  title_pt  \
# 0      tt1825683                   Black Panther        Infiltrado na Klan
# 1      tt7349662                  BlacKkKlansman             Pantera Negra
# 2      tt1727824               Bohemian Rhapsody         Bohemian Rhapsody
# 3      tt5083738                     La favorita                A Favorita
# 4      tt6966692                      Green Book        Green Book: O Guia
# 5      tt1517451                  A Star Is Born         Nasce Uma Estrela
# 6      tt6266538        Vice - L'uomo nell'ombra                      Vice
# 7      tt1950186   Le Mans '66 - La grande sfida           Ford v. Ferrari
# 8      tt1302006                    The Irishman                O Irlandes
# 9      tt2584384                     Jojo Rabbit               Jojo Rabbit
# 10     tt7286456                           Joker                   Coringa
# ...

# %%
nominated8.to_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/nominated8.csv', index=False)

# %%
oscar21  = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/datasets_atual/oscar2021.csv')
oscar21
# Out:
#   imdb_title_id                     title_pt
# 0     tt9784798  Judas and the Black Messiah
# 1    tt10618286                         Mank
# 2    tt10633456                       Minari
# 3     tt9770150                   Nomadland
# 4     tt9620292        Promising Young Woman
# 5     tt5363618               Sound of Metal
# 6    tt10272386                   The Father
# 7     tt1070874   The Trial of the Chicago 7

# %%
nominated2021 = pd.merge(oscar21, nome, on="imdb_title_id")
nominated2021
# Out:
#   imdb_title_id               title_pt                  title  \
# 0    tt10633456                 Minari                 Minari
# 1     tt9620292  Promising Young Woman  Promising Young Woman
# 2     tt5363618         Sound of Metal         Sound of Metal
# 3    tt10272386             The Father             The Father
#
#           original_title  year date_published                 genre  duration  \
# 0                 Minari  2020     2020-11-20                 Drama       115
# 1  Promising Young Woman  2020     2020-07-17  Comedy, Crime, Drama       113
# 2         Sound of Metal  2019           2020          Drama, Music       130
# 3             The Father  2020     2021-01-08                 Drama        97
#
#         country language  ...  \
# 0           USA  English  ...
# 1       UK, USA  English  ...
# 2  Belgium, USA  English  ...
# 3    UK, France  English  ...
#
#                                               actors  \
# ...

# %%
nominated2021.keys()
# Out:
# Index(['imdb_title_id', 'title_pt', 'title', 'original_title', 'year',
#        'date_published', 'genre', 'duration', 'country', 'language',
#        'director', 'writer', 'production_company', 'actors', 'description',
#        'avg_vote', 'votes', 'budget', 'usa_gross_income',
#        'worlwide_gross_income', 'metascore', 'reviews_from_users',
#        'reviews_from_critics'],
#       dtype='object')

# %%
nominated2021 = nominated2021[['imdb_title_id', 'title', 'title_pt', 'year', 'avg_vote', 'votes', 'metascore', 'duration', 'genre', 'director', 'actors',  'writer', 'budget','usa_gross_income', 'worlwide_gross_income', 'description']]

# %%
nominated2021.rename(columns={'duration':'runtime'}, inplace=True)
# Out:
# C:\Users\gisiq\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
nominated2021.keys()
# Out:
# Index(['imdb_title_id', 'title', 'title_pt', 'year', 'avg_vote', 'votes',
#        'metascore', 'runtime', 'genre', 'director', 'actors', 'writer',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'description'],
#       dtype='object')

# %%
nominated2021  = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/datasets_atual/nominated2021.csv')
nominated2021
# Out:
#   imdb_title_id               title_pt                  title  \
# 0    tt10633456                 Minari                 Minari
# 1     tt9620292  Promising Young Woman  Promising Young Woman
# 2     tt5363618         Sound of Metal         Sound of Metal
# 3    tt10272386             The Father             The Father
#
#           original_title  year date_published                 genre  duration  \
# 0                 Minari  2020     2020-11-20                 Drama       115
# 1  Promising Young Woman  2020     2020-07-17  Comedy, Crime, Drama       113
# 2         Sound of Metal  2019           2020          Drama, Music       130
# 3             The Father  2020     2021-01-08                 Drama        97
#
#         country language  ...  \
# 0           USA  English  ...
# 1       UK, USA  English  ...
# 2  Belgium, USA  English  ...
# 3    UK, France  English  ...
#
#                                               actors  \
# ...

# %%
nominated2021 = nominated2021[['imdb_title_id', 'title', 'title_pt', 'year', 'avg_vote', 'votes', 'metascore', 'duration', 'genre', 'director', 'actors',  'writer', 'budget','usa_gross_income', 'worlwide_gross_income', 'description']]

# %%
linha1 = {'imdb_title_id':'tt9784798' ,
          'title': 'Judas and the Black Messiah',
          'title_pt':'Judas e o Messias Negro' ,
          'year': 2020,
          'avg_vote' : 7.6,
          'votes': 37135,
          'metascore': 85 ,
          'duration': 126,
          'genre':'Biography, Drama, History',
          'director': 'Shaka King',
          'actors':'Daniel Kaluuya, LaKeith Stanfield, Jesse Plemons ',
          'writer':'Will Berson',
          'budget':'$26,000,000',
          'usa_gross_income':'$5,352,415',
          'worlwide_gross_income':'$6,057,415',
          'description':"Bill O'Neal infiltrates the Black Panther Party per FBI Agent Mitchell and J. Edgar Hoover. As Party Chairman Fred Hampton ascends, falling for a fellow revolutionary en route, a battle wages for O'Neal's soul"}

# %%
linha2 = {'imdb_title_id':'tt9770150' ,
          'title': 'Nomadland',
          'title_pt':'Nomadland' ,
          'year': 2020,
          'avg_vote' : 7.5,
          'votes': 56344,
          'metascore': 93 ,
          'duration': 107,
          'genre':'Biography, Drama, History',
          'director': 'Chloé Zhao',
          'actors':'Frances McDormand, David Strathairn, Linda May ',
          'writer':'Jessica Bruder ',
          'budget':'$5,000,000',
          'usa_gross_income':'$2,143,000',
          'worlwide_gross_income':'$5,074,445',
          'description':"A woman in her sixties who, after losing everything in the Great Recession, embarks on a journey through the American West, living as a van-dwelling modern-day nomad.l"}

# %%
linha3 = {'imdb_title_id':'tt1070874' ,
          'title': 'The Trial of the Chicago 7',
          'title_pt':'Os 7 de Chicago' ,
          'year': 2020,
          'avg_vote' : 7.8,
          'votes': 131684,
          'metascore': 76 ,
          'duration': 129,
          'genre':'Drama, History, Thriller ',
          'director': 'Aaron Sorkin',
          'actors':'Eddie Redmayne, Alex Sharp, Sacha Baron Cohen',
          'writer':'Aaron Sorkin',
          'budget':'$35,000,000',
          'usa_gross_income':'115,000',
          'worlwide_gross_income':'115,000',
          'description':"The story of 7 people on trial stemming from various charges surrounding the uprising at the 1968 Democratic National Convention in Chicago, Illinois."}

# %%
linha4 = {'imdb_title_id':'tt10618286' ,
          'title': 'Mank',
          'title_pt':'Mank' ,
          'year': 2020,
          'avg_vote' : 7.0,
          'votes': 54050,
          'metascore': 79 ,
          'duration': 131,
          'genre':'Biography, Comedy, Drama',
          'director': 'David Fincher',
          'actors':'Gary Oldman, Amanda Seyfried, Lily Collins',
          'writer':'Jack Fincher',
          'budget':'$25,000,000',
          'usa_gross_income':'122,000',
          'worlwide_gross_income':'$122,000',
          'description':"1930's Hollywood is reevaluated through the eyes of scathing social critic and alcoholic screenwriter Herman J. Mankiewicz as he races to finish the screenplay of Citizen Kane (1941)."}

# %%
nominated2021 = nominated2021.append(linha1,ignore_index=True)

# %%
nominated2021
# Out:
#   imdb_title_id                        title                 title_pt  year  \
# 0    tt10633456                       Minari                   Minari  2020
# 1     tt9620292        Promising Young Woman    Promising Young Woman  2020
# 2     tt5363618               Sound of Metal           Sound of Metal  2019
# 3    tt10272386                   The Father               The Father  2020
# 4     tt9784798  Judas and the Black Messiah  Judas e o Messias Negro  2020
#
#    avg_vote  votes  metascore  duration                      genre  \
# 0       8.0    167       88.0       115                      Drama
# 1       6.5    349       74.0       113       Comedy, Crime, Drama
# 2       6.9    307       87.0       130               Drama, Music
# 3       8.2    148       87.0        97                      Drama
# 4       7.6  37135       85.0       126  Biography, Drama, History
#
#           director                                             actors  \
# ...

# %%
nominated2021 = nominated2021.append(linha2,ignore_index=True)

# %%
nominated2021 = nominated2021.append(linha3,ignore_index=True)

# %%
nominated2021 = nominated2021.append(linha4,ignore_index=True)

# %%
nominated2021
# Out:
#   imdb_title_id                        title                 title_pt  year  \
# 0    tt10633456                       Minari                   Minari  2020
# 1     tt9620292        Promising Young Woman    Promising Young Woman  2020
# 2     tt5363618               Sound of Metal           Sound of Metal  2019
# 3    tt10272386                   The Father               The Father  2020
# 4     tt9784798  Judas and the Black Messiah  Judas e o Messias Negro  2020
# 5     tt9770150                    Nomadland                Nomadland  2020
# 6     tt1070874   The Trial of the Chicago 7          Os 7 de Chicago  2020
# 7    tt10618286                         Mank                     Mank  2020
#
#    avg_vote   votes  metascore  duration                      genre  \
# 0       8.0     167       88.0       115                      Drama
# 1       6.5     349       74.0       113       Comedy, Crime, Drama
# 2       6.9     307       87.0       130               Drama, Music
# ...

# %%
nominated2021.at[0, 'title_pt'] = 'Minari'
nominated2021.at[0,'year'] = 2020
nominated2021.at[0,'budget']= '$2,000,000'
nominated2021.at[0,'usa_gross_income'] ='$11,000,000'
nominated2021.at[0,'worlwide_gross_income'] = '$11,000,000'
              
    
nominated2021.at[1, 'title_pt'] = 'Bela Vingança'
nominated2021.at[1,'year'] = 2020
nominated2021.at[1,'budget']= '$2,000,000'
nominated2021.at[1,'usa_gross_income'] ='$5,808,915'
nominated2021.at[1,'worlwide_gross_income'] = '$10,912,915'  
    
nominated2021.at[2, 'title_pt'] = 'O Som do Silêncio'
nominated2021.at[2,'year'] = 2020
nominated2021.at[2,'budget']= '$1,000,000'
nominated2021.at[2,'usa_gross_income'] ='$180,000'
nominated2021.at[2,'worlwide_gross_income'] = '$180,000'      
    
nominated2021.at[3, 'title_pt'] = 'Meu Pai'
nominated2021.at[3,'year'] = 2020
nominated2021.at[3,'budget']= '$20,000,000'
nominated2021.at[3,'usa_gross_income'] ='$5,100,000'
nominated2021.at[3,'worlwide_gross_income'] = '$5,100,000'

# %%
nominated2021
# Out:
#   imdb_title_id                        title                 title_pt  year  \
# 0    tt10633456                       Minari                   Minari  2020
# 1     tt9620292        Promising Young Woman            Bela Vingança  2020
# 2     tt5363618               Sound of Metal        O Som do Silêncio  2020
# 3    tt10272386                   The Father                  Meu Pai  2020
# 4     tt9784798  Judas and the Black Messiah  Judas e o Messias Negro  2020
# 5     tt9770150                    Nomadland                Nomadland  2020
# 6     tt1070874   The Trial of the Chicago 7          Os 7 de Chicago  2020
# 7    tt10618286                         Mank                     Mank  2020
#
#    avg_vote   votes  metascore  duration                      genre  \
# 0       8.0     167       88.0       115                      Drama
# 1       6.5     349       74.0       113       Comedy, Crime, Drama
# 2       6.9     307       87.0       130               Drama, Music
# ...

# %%
nominated2021['metascore'] = nominated2021['metascore'].div(10).round(1)
nominated2021['metascore']
# Out:
# 0    8.8
# 1    7.4
# 2    8.7
# 3    8.7
# 4    8.5
# 5    9.3
# 6    7.6
# 7    7.9
# Name: metascore, dtype: float64

# %%
nominated2021['budget'] = nominated2021['budget'].replace({r'\$|GBP|EUR|,':''}, regex = True)
nominated2021['usa_gross_income'] = nominated2021['usa_gross_income'].replace({r'\$|GBP|EUR|,':''}, regex = True)
nominated2021['worlwide_gross_income'] = nominated2021['worlwide_gross_income'].replace({r'\$|GBP|EUR|,':''}, regex = True)

# %%
nominated2021
# Out:
#   imdb_title_id                        title                 title_pt  year  \
# 0    tt10633456                       Minari                   Minari  2020
# 1     tt9620292        Promising Young Woman            Bela Vingança  2020
# 2     tt5363618               Sound of Metal        O Som do Silêncio  2020
# 3    tt10272386                   The Father                  Meu Pai  2020
# 4     tt9784798  Judas and the Black Messiah  Judas e o Messias Negro  2020
# 5     tt9770150                    Nomadland                Nomadland  2020
# 6     tt1070874   The Trial of the Chicago 7          Os 7 de Chicago  2020
# 7    tt10618286                         Mank                     Mank  2020
#
#    avg_vote   votes  metascore  duration                      genre  \
# 0       8.0     167        8.8       115                      Drama
# 1       6.5     349        7.4       113       Comedy, Crime, Drama
# 2       6.9     307        8.7       130               Drama, Music
# ...

# %%
nominated2021.year = [y.year for y in pd.to_datetime(nominated2021.year.astype('int'), format='%Y')]
nominated2021.reset_index(drop=True)
# Out:
#   imdb_title_id                        title                 title_pt  year  \
# 0    tt10633456                       Minari                   Minari  2020
# 1     tt9620292        Promising Young Woman            Bela Vingança  2020
# 2     tt5363618               Sound of Metal        O Som do Silêncio  2020
# 3    tt10272386                   The Father                  Meu Pai  2020
# 4     tt9784798  Judas and the Black Messiah  Judas e o Messias Negro  2020
# 5     tt9770150                    Nomadland                Nomadland  2020
# 6     tt1070874   The Trial of the Chicago 7          Os 7 de Chicago  2020
# 7    tt10618286                         Mank                     Mank  2020
#
#    avg_vote   votes  metascore  duration                      genre  \
# 0       8.0     167        8.8       115                      Drama
# 1       6.5     349        7.4       113       Comedy, Crime, Drama
# 2       6.9     307        8.7       130               Drama, Music
# ...

# %%
nominated2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          8 non-null      object
#  1   title                  8 non-null      object
#  2   title_pt               8 non-null      object
#  3   year                   8 non-null      int64
#  4   avg_vote               8 non-null      float64
#  5   votes                  8 non-null      int64
#  6   metascore              8 non-null      float64
#  7   duration               8 non-null      int64
#  8   genre                  8 non-null      object
#  9   director               8 non-null      object
#  10  actors                 8 non-null      object
#  11  writer                 8 non-null      object
#  12  budget                 8 non-null      object
#  13  usa_gross_income       8 non-null      object
# ...

# %%
nominated2021['budget'] = nominated2021['budget'].astype(str).astype(int)

# %%
nominated2021['usa_gross_income'] = nominated2021['usa_gross_income'].astype(str).astype(int)
nominated2021['worlwide_gross_income'] = nominated2021['worlwide_gross_income'].astype(str).astype(int)

# %%
nominated2021['win'] = 0

# %%
nominated2021.rename(columns={'duration':'runtime'}, inplace=True)

# %%
nominated2021
# Out:
#   imdb_title_id                        title                 title_pt  year  \
# 0    tt10633456                       Minari                   Minari  2020
# 1     tt9620292        Promising Young Woman            Bela Vingança  2020
# 2     tt5363618               Sound of Metal        O Som do Silêncio  2020
# 3    tt10272386                   The Father                  Meu Pai  2020
# 4     tt9784798  Judas and the Black Messiah  Judas e o Messias Negro  2020
# 5     tt9770150                    Nomadland                Nomadland  2020
# 6     tt1070874   The Trial of the Chicago 7          Os 7 de Chicago  2020
# 7    tt10618286                         Mank                     Mank  2020
#
#    avg_vote   votes  metascore  runtime                      genre  \
# 0       8.0     167        8.8      115                      Drama
# 1       6.5     349        7.4      113       Comedy, Crime, Drama
# 2       6.9     307        8.7      130               Drama, Music
# ...

# %%
nominated2021.to_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/datasets_atual/oscar_2021_clean.csv', index=False)
