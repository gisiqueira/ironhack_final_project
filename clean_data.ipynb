# %%
import pandas as pd
import numpy as np

# %%
all_oscar = pd.read_csv('all_oscar.csv')

# %%
all_oscar
# Out:
#     imdb_title_id                             title  \
# 0       tt6294822                          The Post
# 1       tt5776858                  Il filo nascosto
# 2       tt5027774  Tre manifesti a Ebbing, Missouri
# 3       tt4925292                         Lady Bird
# 4       tt4555426                    L'ora più buia
# ..            ...                               ...
# 542     tt3281548                     Piccole donne
# 543     tt7653254           Storia di un matrimonio
# 544     tt8579674                              1917
# 545     tt7131622    C'era una volta a... Hollywood
# 546     tt6751668                          Parasite
#
#                         title_pt  year  avg_vote   votes  metascore  runtime  \
# 0     The Post: A Guerra Secreta  2017       7.2  130017       83.0      116
# 1                 Trama Fantasma  2017       7.5  106231       90.0      130
# 2    Três Anúncios para um Crime  2017       8.2  411693       88.0      115
# ...

# %%
all_oscar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          547 non-null    object
#  1   title                  547 non-null    object
#  2   title_pt               547 non-null    object
#  3   year                   547 non-null    int64
#  4   avg_vote               547 non-null    float64
#  5   votes                  547 non-null    int64
#  6   metascore              374 non-null    float64
#  7   runtime                547 non-null    int64
#  8   genre                  547 non-null    object
#  9   director               547 non-null    object
#  10  actors                 547 non-null    object
#  11  writer                 547 non-null    object
#  12  budget                 431 non-null    object
#  13  usa_gross_income       333 non-null    object
# ...

# %%
all_oscar.metascore.unique()
# Out:
# array([ 83.,  90.,  88.,  94.,  75.,  87.,  85.,  93.,  79.,  74.,  69.,
#         71.,  99.,  81.,  96.,  76.,  80.,  86.,  72.,  73., 100.,  82.,
#         77.,  95.,  63.,  46.,  84.,  62.,  89.,  92.,  53.,  78.,  70.,
#         58.,  91.,  66.,  67.,  64.,  61.,  59.,  68.,  65.,  60.,  52.,
#         57.,  97.,  55.,  nan,  42.,  51.,  34.,  48.,  56.,  98.,  49.])

# %%
all_oscar['metascore'] = all_oscar['metascore'].div(10).round(1)
all_oscar['metascore']
# Out:
# 0      8.3
# 1      9.0
# 2      8.8
# 3      9.4
# 4      7.5
#       ...
# 542    9.1
# 543    9.4
# 544    7.8
# 545    8.3
# 546    9.6
# Name: metascore, Length: 547, dtype: float64

# %%
all_oscar.budget.unique()
# Out:
# array(['$ 50000000', '$ 35000000', '$ 15000000', '$ 10000000',
#        '$ 30000000', '$ 19400000', '$ 100000000', '$ 4500000',
#        'EUR 4000000', '$ 24000000', '$ 25000000', '$ 12000000',
#        '$ 40000000', '$ 4000000', '$ 47000000', '$ 9000000',
#        '$ 135000000', '$ 28000000', '$ 108000000', '$ 13000000',
#        '$ 20000000', '$ 150000000', '$ 11000000', '$ 58800000',
#        '$ 14000000', '$ 18000000', '$ 3300000', '$ 23000000',
#        '$ 55000000', '$ 5000000', '$ 61000000', '$ 65000000',
#        '$ 120000000', '$ 21000000', '$ 44500000', '$ 8900000',
#        '$ 1800000', '$ 66000000', '$ 32000000', '$ 17000000',
#        '$ 38000000', '$ 160000000', '$ 200000000', '$ 2000000',
#        '$ 237000000', '$ 29000000', '$ 7000000', '$ 70000000',
#        '$ 175000000', '$ 7500000', '$ 19000000', '$ 90000000',
#        'GBP 9800000', '$ 8000000', '$ 110000000', '$ 16000000',
#        '$ 6500000', '$ 94000000', '$ 87000000', '$ 45000000',
# ...

# %%
all_oscar['budget'] = all_oscar['budget'].replace({r'\$':''}, regex = True)

# %%
all_oscar['budget'] = all_oscar['budget'].replace({r'GBP':''}, regex = True)
all_oscar['budget'] = all_oscar['budget'].replace({r'EUR':''}, regex = True)

# %%
all_oscar['budget']
# Out:
# 0       50000000
# 1       35000000
# 2       15000000
# 3       10000000
# 4       30000000
#          ...
# 542     40000000
# 543     18600000
# 544     95000000
# 545     90000000
# 546     11400000
# Name: budget, Length: 547, dtype: object

# %%
all_oscar['usa_gross_income'] = all_oscar['usa_gross_income'].replace({r'\$':''}, regex = True)
all_oscar['usa_gross_income'] = all_oscar['usa_gross_income'].replace({r'GBP':''}, regex = True)
all_oscar['usa_gross_income'] = all_oscar['usa_gross_income'].replace({r'EUR':''}, regex = True)

# %%
all_oscar['worlwide_gross_income'] = all_oscar['worlwide_gross_income'].replace({r'\$':''}, regex = True)
all_oscar['worlwide_gross_income'] = all_oscar['worlwide_gross_income'].replace({r'GBP':''}, regex = True)
all_oscar['worlwide_gross_income'] = all_oscar['worlwide_gross_income'].replace({r'EUR':''}, regex = True)

# %%
all_oscar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          547 non-null    object
#  1   title                  547 non-null    object
#  2   title_pt               547 non-null    object
#  3   year                   547 non-null    int64
#  4   avg_vote               547 non-null    float64
#  5   votes                  547 non-null    int64
#  6   metascore              374 non-null    float64
#  7   runtime                547 non-null    int64
#  8   genre                  547 non-null    object
#  9   director               547 non-null    object
#  10  actors                 547 non-null    object
#  11  writer                 547 non-null    object
#  12  budget                 431 non-null    object
#  13  usa_gross_income       333 non-null    object
# ...

# %%
all_oscar.year = [y.year for y in pd.to_datetime(all_oscar.year.astype('int'), format='%Y')]
all_oscar.reset_index(drop=True)
# Out:
#     imdb_title_id                             title  \
# 0       tt6294822                          The Post
# 1       tt5776858                  Il filo nascosto
# 2       tt5027774  Tre manifesti a Ebbing, Missouri
# 3       tt4925292                         Lady Bird
# 4       tt4555426                    L'ora più buia
# ..            ...                               ...
# 542     tt3281548                     Piccole donne
# 543     tt7653254           Storia di un matrimonio
# 544     tt8579674                              1917
# 545     tt7131622    C'era una volta a... Hollywood
# 546     tt6751668                          Parasite
#
#                         title_pt  year  avg_vote   votes  metascore  runtime  \
# 0     The Post: A Guerra Secreta  2017       7.2  130017        8.3      116
# 1                 Trama Fantasma  2017       7.5  106231        9.0      130
# 2    Três Anúncios para um Crime  2017       8.2  411693        8.8      115
# ...

# %%
all_oscar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          547 non-null    object
#  1   title                  547 non-null    object
#  2   title_pt               547 non-null    object
#  3   year                   547 non-null    int64
#  4   avg_vote               547 non-null    float64
#  5   votes                  547 non-null    int64
#  6   metascore              374 non-null    float64
#  7   runtime                547 non-null    int64
#  8   genre                  547 non-null    object
#  9   director               547 non-null    object
#  10  actors                 547 non-null    object
#  11  writer                 547 non-null    object
#  12  budget                 431 non-null    object
#  13  usa_gross_income       333 non-null    object
# ...

# %%
all_oscar.isnull().sum()
# Out:
# imdb_title_id              0
# title                      0
# title_pt                   0
# year                       0
# avg_vote                   0
# votes                      0
# metascore                173
# runtime                    0
# genre                      0
# director                   0
# actors                     0
# writer                     0
# budget                   116
# usa_gross_income         214
# worlwide_gross_income    196
# description                3
# dtype: int64

# %%
all_oscar2['budget'] = all_oscar['budget'].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-f67d4528ddd5> in <module>
# ----> 1 all_oscar2['budget'] = all_oscar['budget'].astype(str).astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
all_oscar.metascore = all_oscar.metascore.fillna(all_oscar.avg_vote)

# %%
all_oscar.isnull().sum()
# Out:
# imdb_title_id              0
# title                      0
# title_pt                   0
# year                       0
# avg_vote                   0
# votes                      0
# metascore                173
# runtime                    0
# genre                      0
# director                   0
# actors                     0
# writer                     0
# budget                   116
# usa_gross_income         214
# worlwide_gross_income    196
# description                3
# dtype: int64

# %%
all_oscar.budget = all_oscar.budget.fillna('0')

# %%
all_oscar.isnull().sum()
# Out:
# imdb_title_id              0
# title                      0
# title_pt                   0
# year                       0
# avg_vote                   0
# votes                      0
# metascore                173
# runtime                    0
# genre                      0
# director                   0
# actors                     0
# writer                     0
# budget                     0
# usa_gross_income         214
# worlwide_gross_income    196
# description                3
# dtype: int64

# %%
all_oscar.usa_gross_income  = all_oscar.usa_gross_income.fillna('0')
all_oscar.worlwide_gross_income  = all_oscar.worlwide_gross_income.fillna('0')
all_oscar.description  = all_oscar.description.fillna('0')

# %%
all_oscar.isnull().sum()
# Out:
# imdb_title_id              0
# title                      0
# title_pt                   0
# year                       0
# avg_vote                   0
# votes                      0
# metascore                173
# runtime                    0
# genre                      0
# director                   0
# actors                     0
# writer                     0
# budget                     0
# usa_gross_income           0
# worlwide_gross_income      0
# description                0
# dtype: int64

# %%
all_oscar['budget'] = all_oscar['budget'].astype(str)

# %%
all_oscar['budget'] = np.dtype('int64').type(all_oscar['budget'])

# %%
all_oscar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          547 non-null    object
#  1   title                  547 non-null    object
#  2   title_pt               547 non-null    object
#  3   year                   547 non-null    int64
#  4   avg_vote               547 non-null    float64
#  5   votes                  547 non-null    int64
#  6   metascore              374 non-null    float64
#  7   runtime                547 non-null    int64
#  8   genre                  547 non-null    object
#  9   director               547 non-null    object
#  10  actors                 547 non-null    object
#  11  writer                 547 non-null    object
#  12  budget                 547 non-null    int64
#  13  usa_gross_income       547 non-null    object
# ...

# %%
all_oscar['usa_gross_income'] = all_oscar['usa_gross_income'].astype(str)

# %%
all_oscar['usa_gross_income'] = np.dtype('int64').type(all_oscar['usa_gross_income'])

# %%
all_oscar['worlwide_gross_income'] = all_oscar['worlwide_gross_income'].astype(str)

# %%
all_oscar['worlwide_gross_income'] = np.dtype('int64').type(all_oscar['worlwide_gross_income'])

# %%
all_oscar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          547 non-null    object
#  1   title                  547 non-null    object
#  2   title_pt               547 non-null    object
#  3   year                   547 non-null    int64
#  4   avg_vote               547 non-null    float64
#  5   votes                  547 non-null    int64
#  6   metascore              374 non-null    float64
#  7   runtime                547 non-null    int64
#  8   genre                  547 non-null    object
#  9   director               547 non-null    object
#  10  actors                 547 non-null    object
#  11  writer                 547 non-null    object
#  12  budget                 547 non-null    int64
#  13  usa_gross_income       547 non-null    int64
# ...

# %%
code_winners = pd.read_csv('code_winners.csv')

# %%
all_oscar2 = pd.merge(all_oscar, code_winners, on="imdb_title_id", how = 'outer').fillna(0)
all_oscar2
# Out:
#     imdb_title_id                             title  \
# 0       tt6294822                          The Post
# 1       tt5776858                  Il filo nascosto
# 2       tt5027774  Tre manifesti a Ebbing, Missouri
# 3       tt4925292                         Lady Bird
# 4       tt4555426                    L'ora più buia
# ..            ...                               ...
# 545     tt7131622    C'era una volta a... Hollywood
# 546     tt6751668                          Parasite
# 547     tt0887912                                 0
# 548     tt0077416                                 0
# 549     tt0018455                                 0
#
#                         title_pt    year  avg_vote     votes  metascore  \
# 0     The Post: A Guerra Secreta  2017.0       7.2  130017.0        8.3
# 1                 Trama Fantasma  2017.0       7.5  106231.0        9.0
# 2    Três Anúncios para um Crime  2017.0       8.2  411693.0        8.8
# ...

# %%
all_oscar2 = all_oscar2.iloc[:-3 , :]

# %%
all_oscar2
# Out:
#     imdb_title_id                             title  \
# 0       tt6294822                          The Post
# 1       tt5776858                  Il filo nascosto
# 2       tt5027774  Tre manifesti a Ebbing, Missouri
# 3       tt4925292                         Lady Bird
# 4       tt4555426                    L'ora più buia
# ..            ...                               ...
# 542     tt3281548                     Piccole donne
# 543     tt7653254           Storia di un matrimonio
# 544     tt8579674                              1917
# 545     tt7131622    C'era una volta a... Hollywood
# 546     tt6751668                          Parasite
#
#                         title_pt    year  avg_vote     votes  metascore  \
# 0     The Post: A Guerra Secreta  2017.0       7.2  130017.0        8.3
# 1                 Trama Fantasma  2017.0       7.5  106231.0        9.0
# 2    Três Anúncios para um Crime  2017.0       8.2  411693.0        8.8
# ...

# %%
all_oscar2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 547 entries, 0 to 546
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          547 non-null    object
#  1   title                  547 non-null    object
#  2   title_pt               547 non-null    object
#  3   year                   547 non-null    float64
#  4   avg_vote               547 non-null    float64
#  5   votes                  547 non-null    float64
#  6   metascore              547 non-null    float64
#  7   runtime                547 non-null    float64
#  8   genre                  547 non-null    object
#  9   director               547 non-null    object
#  10  actors                 547 non-null    object
#  11  writer                 547 non-null    object
#  12  budget                 547 non-null    float64
#  13  usa_gross_income       547 non-null    float64
# ...

# %%
all_oscar2.to_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/oscar_historic_clean.csv', index=False)

# %%
nome  = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/datasets_atual/oscar_2021_clean.csv')

# %%
nome
# Out:
#   imdb_title_id                        title                 title_pt  year  \
# 0    tt10633456                       Minari                   Minari  2020
# 1     tt9620292        Promising Young Woman            Bela Vingança  2020
# 2     tt5363618               Sound of Metal        O Som do Silêncio  2020
# 3    tt10272386                   The Father                  Meu Pai  2020
# 4     tt9784798  Judas and the Black Messiah  Judas e o Messias Negro  2020
# 5     tt9770150                    Nomadland                Nomadland  2020
# 6     tt1070874   The Trial of the Chicago 7          Os 7 de Chicago  2020
# 7    tt10618286                         Mank                     Mank  2020
#
#    avg_vote   votes  metascore  runtime                      genre  \
# 0       8.0     167        8.8      115                      Drama
# 1       6.5     349        7.4      113       Comedy, Crime, Drama
# 2       6.9     307        8.7      130               Drama, Music
# ...

# %%
oscar_model = pd.concat([all_oscar2, nome])

# %%
oscar_model
# Out:
#    imdb_title_id                             title  \
# 0      tt6294822                          The Post
# 1      tt5776858                  Il filo nascosto
# 2      tt5027774  Tre manifesti a Ebbing, Missouri
# 3      tt4925292                         Lady Bird
# 4      tt4555426                    L'ora più buia
# ..           ...                               ...
# 3     tt10272386                        The Father
# 4      tt9784798       Judas and the Black Messiah
# 5      tt9770150                         Nomadland
# 6      tt1070874        The Trial of the Chicago 7
# 7     tt10618286                              Mank
#
#                        title_pt    year  avg_vote     votes  metascore  \
# 0    The Post: A Guerra Secreta  2017.0       7.2  130017.0        8.3
# 1                Trama Fantasma  2017.0       7.5  106231.0        9.0
# 2   Três Anúncios para um Crime  2017.0       8.2  411693.0        8.8
# ...

# %%
oscar_model['year'] = oscar_model['year'].apply(np.int64)
oscar_model['win'] = oscar_model['win'].apply(np.int64)

# %%
oscar_model.to_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/oscar_model.csv', index=False)

# %%
extra_info1 = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/data/New folder/workshop-notebooks-master/notebooks/oscars/train.csv')

# %%
extra_info1
# Out:
#      Year                            Movie  Won?       Budget  \
# 0    2017             Call Me By Your Name     0    3500000.0
# 1    2017                     Darkest Hour     0   30000000.0
# 2    2017                          Dunkirk     0  100000000.0
# 3    2017                          Get Out     0    4500000.0
# 4    2017                        Lady Bird     0   10000000.0
# ..    ...                              ...   ...          ...
# 221  1975                     Barry Lyndon     0   11000000.0
# 222  1975                Dog Day Afternoon     0    1800000.0
# 223  1975                             Jaws     0    8000000.0
# 224  1975                        Nashville     0    2200000.0
# 225  1975  One Flew over the Cuckoo's Nest     1    4400000.0
#
#      Opening Weekend  IMDB Rating                             Genres  \
# 0           412932.0          8.3                     Drama, Romance
# 1          2993519.0          7.4          Biography, Drama, History
# ...

# %%
extra_info1 = extra_info1[['IMdB id', 'Won Golden Globe', 'Won Bafta', 'Oscar Nominations','Golden Globe Nominations', 'Bafta Nominations','Won Directors','Won Actors']]

# %%
extra_info1
# Out:
#        IMdB id  Won Golden Globe  Won Bafta  Oscar Nominations  \
# 0    tt5726616                 0          0                  4
# 1    tt4555426                 0          0                  6
# 2    tt5013056                 0          0                  8
# 3    tt5052448                 0          0                  4
# 4    tt4925292                 1          0                  5
# ..         ...               ...        ...                ...
# 221  tt0072684                 0          0                  7
# 222  tt0072890                 0          1                  6
# 223  tt0073195                 0          0                  4
# 224  tt0073440                 0          0                  5
# 225  tt0073486                 1          1                  9
#
#      Golden Globe Nominations  Bafta Nominations  Won Directors  Won Actors
# 0                           3                  4              0           0
# ...

# %%
extra_info2 = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/data/New folder/workshop-notebooks-master/notebooks/oscars/test.csv')

# %%
extra_info2
# Out:
#     Year                                            Movie  Won?       Budget  \
# 0   2018                                   A Star is Born   NaN   36000000.0
# 1   2018                                  BlacKkKclansman   NaN   15000000.0
# 2   2018                                    Black Panther   NaN  200000000.0
# 3   2018                                Bohemian Rhapsody   NaN   52000000.0
# 4   2018                                       Green Book   NaN   23000000.0
# 5   2018                                             Roma   NaN   15000000.0
# 6   2018                                    The Favourite   NaN   15000000.0
# 7   2018                                             Vice   NaN   60000000.0
# 8   2009                                           Avatar   0.0  237000000.0
# 9   2009                                   The Blind Side   0.0   29000000.0
# 10  2009                                       District 9   0.0   30000000.0
# ...

# %%
extra_info2 = extra_info2[['IMdB id', 'Won Golden Globe', 'Won Bafta', 'Oscar Nominations','Golden Globe Nominations', 'Bafta Nominations','Won Directors','Won Actors']]

# %%
extra = extra_info1.append(extra_info2, ignore_index=True)

# %%
extra
# Out:
#        IMdB id  Won Golden Globe  Won Bafta  Oscar Nominations  \
# 0    tt5726616                 0          0                  4
# 1    tt4555426                 0          0                  6
# 2    tt5013056                 0          0                  8
# 3    tt5052448                 0          0                  4
# 4    tt4925292                 1          0                  5
# ..         ...               ...        ...                ...
# 254  tt0074119                 0          0                  8
# 255  tt0074235                 0          0                  6
# 256  tt0074958                 0          0                 10
# 257  tt0075148                 1          0                 10
# 258  tt0075314                 0          0                  4
#
#      Golden Globe Nominations  Bafta Nominations  Won Directors  Won Actors
# 0                           3                  4              0           0
# ...

# %%
extra.rename(columns={'IMdB id':'imdb_title_id'}, inplace=True)

# %%
oscar_model = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/oscar_model.csv')

# %%
oscar_model_extra = pd.merge(left=oscar_model, right=extra, how='left', left_on='imdb_title_id', right_on='imdb_title_id')
oscar_model_extra
# Out:
#     imdb_title_id                             title  \
# 0       tt6294822                          The Post
# 1       tt5776858                  Il filo nascosto
# 2       tt5027774  Tre manifesti a Ebbing, Missouri
# 3       tt4925292                         Lady Bird
# 4       tt4555426                    L'ora più buia
# ..            ...                               ...
# 550    tt10272386                        The Father
# 551     tt9784798       Judas and the Black Messiah
# 552     tt9770150                         Nomadland
# 553     tt1070874        The Trial of the Chicago 7
# 554    tt10618286                              Mank
#
#                         title_pt  year  avg_vote     votes  metascore  \
# 0     The Post: A Guerra Secreta  2017       7.2  130017.0        8.3
# 1                 Trama Fantasma  2017       7.5  106231.0        9.0
# 2    Três Anúncios para um Crime  2017       8.2  411693.0        8.8
# ...

# %%
oscar_model_extra.keys()
# Out:
# Index(['imdb_title_id', 'title', 'title_pt', 'year', 'avg_vote', 'votes',
#        'metascore', 'runtime', 'genre', 'director', 'actors', 'writer',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'description',
#        'win', 'Won Golden Globe', 'Won Bafta', 'Oscar Nominations',
#        'Golden Globe Nominations', 'Bafta Nominations', 'Won Directors',
#        'Won Actors'],
#       dtype='object')

# %%
oscar_model_info_last2 = oscar_model_extra.loc[oscar_model_final['year'] >= 2019]

# %%
oscar_model_info_last2
# Out:
#     imdb_title_id                           title                  title_pt  \
# 538     tt1950186   Le Mans '66 - La grande sfida           Ford v. Ferrari
# 539     tt1302006                    The Irishman                O Irlandes
# 540     tt2584384                     Jojo Rabbit               Jojo Rabbit
# 541     tt7286456                           Joker                   Coringa
# 542     tt3281548                   Piccole donne        Adoraveis Mulheres
# 543     tt7653254         Storia di un matrimonio  História de um Casamento
# 544     tt8579674                            1917                      1917
# 545     tt7131622  C'era una volta a... Hollywood  Era uma vez em Hollywood
# 546     tt6751668                        Parasite                  Parasita
# 547    tt10633456                          Minari                    Minari
# 548     tt9620292           Promising Young Woman             Bela Vingança
# ...

# %%
oscar_model_info_last2y = oscar_model_info_last2.drop(columns=['Won Golden Globe','Won Bafta','Oscar Nominations','Golden Globe Nominations','Bafta Nominations','Won Directors','Won Actors'])

# %%
oscar_model_info_last2y
# Out:
#     imdb_title_id                           title                  title_pt  \
# 538     tt1950186   Le Mans '66 - La grande sfida           Ford v. Ferrari
# 539     tt1302006                    The Irishman                O Irlandes
# 540     tt2584384                     Jojo Rabbit               Jojo Rabbit
# 541     tt7286456                           Joker                   Coringa
# 542     tt3281548                   Piccole donne        Adoraveis Mulheres
# 543     tt7653254         Storia di un matrimonio  História de um Casamento
# 544     tt8579674                            1917                      1917
# 545     tt7131622  C'era una volta a... Hollywood  Era uma vez em Hollywood
# 546     tt6751668                        Parasite                  Parasita
# 547    tt10633456                          Minari                    Minari
# 548     tt9620292           Promising Young Woman             Bela Vingança
# ...

# %%
info_last2y = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/data/info_past2y.csv')

# %%
info_last2y
# Out:
#    imdb_title_id  Won Golden Globe  Won Bafta  Oscar Nominations  \
# 0     tt10633456                 0          0                  6
# 1      tt9620292                 0          0                  5
# 2      tt5363618                 0          0                  6
# 3     tt10272386                 0          0                  6
# 4      tt9784798                 0          0                  5
# 5      tt9770150                 1          1                  6
# 6      tt1070874                 0          0                  5
# 7     tt10618286                 0          0                 10
# 8      tt8579674                 1          1                 10
# 9      tt1302006                 0          0                 10
# 10     tt7286456                 0          0                 11
# 11     tt7131622                 0          0                 10
# 12     tt6751668                 0          0                  6
# ...

# %%
info_last_2years = pd.merge(left=oscar_model_info_last2y, right=info_last2y, how='left', left_on='imdb_title_id', right_on='imdb_title_id')
info_last_2years
# Out:
#    imdb_title_id                           title                  title_pt  \
# 0      tt1950186   Le Mans '66 - La grande sfida           Ford v. Ferrari
# 1      tt1302006                    The Irishman                O Irlandes
# 2      tt2584384                     Jojo Rabbit               Jojo Rabbit
# 3      tt7286456                           Joker                   Coringa
# 4      tt3281548                   Piccole donne        Adoraveis Mulheres
# 5      tt7653254         Storia di un matrimonio  História de um Casamento
# 6      tt8579674                            1917                      1917
# 7      tt7131622  C'era una volta a... Hollywood  Era uma vez em Hollywood
# 8      tt6751668                        Parasite                  Parasita
# 9     tt10633456                          Minari                    Minari
# 10     tt9620292           Promising Young Woman             Bela Vingança
# ...

# %%
info_last_2years.keys()
# Out:
# Index(['imdb_title_id', 'title', 'title_pt', 'year', 'avg_vote', 'votes',
#        'metascore', 'runtime', 'genre', 'director', 'actors', 'writer',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'description',
#        'win', 'Won Golden Globe', 'Won Bafta', 'Oscar Nominations',
#        'Golden Globe Nominations', 'Bafta Nominations', 'Won Directors',
#        'Won Actors'],
#       dtype='object')

# %%
oscar_model_final = oscar_model_info.append(info_last_2years, ignore_index=True)
oscar_model_final
# Out:
#     imdb_title_id                             title  \
# 0       tt6294822                          The Post
# 1       tt5776858                  Il filo nascosto
# 2       tt5027774  Tre manifesti a Ebbing, Missouri
# 3       tt4925292                         Lady Bird
# 4       tt4555426                    L'ora più buia
# ..            ...                               ...
# 550    tt10272386                        The Father
# 551     tt9784798       Judas and the Black Messiah
# 552     tt9770150                         Nomadland
# 553     tt1070874        The Trial of the Chicago 7
# 554    tt10618286                              Mank
#
#                         title_pt  year  avg_vote     votes  metascore  \
# 0     The Post: A Guerra Secreta  2017       7.2  130017.0        8.3
# 1                 Trama Fantasma  2017       7.5  106231.0        9.0
# 2    Três Anúncios para um Crime  2017       8.2  411693.0        8.8
# ...

# %%
oscar_model_final.isnull().sum()
# Out:
# imdb_title_id                 0
# title                         0
# title_pt                      0
# year                          0
# avg_vote                      0
# votes                         0
# metascore                     0
# runtime                       0
# genre                         0
# director                      0
# actors                        0
# writer                        0
# budget                        0
# usa_gross_income              0
# worlwide_gross_income         0
# description                   0
# win                           0
# Won Golden Globe            288
# Won Bafta                   288
# Oscar Nominations           288
# Golden Globe Nominations    288
# Bafta Nominations           288
# Won Directors               288
# Won Actors                  288
# dtype: int64

# %%
oscar_model_final.fillna(0, inplace = True)

# %%
oscar_model_final.isnull().sum()
# Out:
# imdb_title_id               0
# title                       0
# title_pt                    0
# year                        0
# avg_vote                    0
# votes                       0
# metascore                   0
# runtime                     0
# genre                       0
# director                    0
# actors                      0
# writer                      0
# budget                      0
# usa_gross_income            0
# worlwide_gross_income       0
# description                 0
# win                         0
# Won Golden Globe            0
# Won Bafta                   0
# Oscar Nominations           0
# Golden Globe Nominations    0
# Bafta Nominations           0
# Won Directors               0
# Won Actors                  0
# dtype: int64

# %%
oscar_model_final.to_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/oscar_model_final.csv')

# %%
oscar_model_final = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/oscar_model_final.csv')

# %%
rotten = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/data/New folder/Predicting-2020-Oscars-master/my_data/df_movies_FINAL.csv')

# %%
rotten
# Out:
#        Unnamed: 0      imdbID                                          title  \
# 0               0   tt0054380                                  the 3rd voice
# 1               1   tt0053561                                5 branded women
# 2               2   tt0054415                                 12 to the moon
# 3               3   tt0053558                                13 fighting men
# 4               4   tt0053559                                      13 ghosts
# ...           ...         ...                                            ...
# 13952       16256   tt7715070  horrible histories: the movie – rotten romans
# 13953       16257  tt10121372                        roger waters: us + them
# 13954       16258   tt6193408           a shaun the sheep movie: farmageddon
# 13955       16259   tt6751668                                       parasite
# 13956       16260   tt8291806                                 pain and glory
#
# ...

# %%
rotten = rotten[['imdbID', 'rotten_tomatoes']]

# %%
rotten.rename(columns={'imdbID':'imdb_title_id'}, inplace=True)

# %%
oscar_model_final = pd.merge(left=oscar_model_final, right=rotten, how='left', left_on='imdb_title_id', right_on='imdb_title_id')
oscar_model_final
# Out:
#      Unnamed: 0 imdb_title_id                             title  \
# 0             0     tt6294822                          The Post
# 1             1     tt5776858                  Il filo nascosto
# 2             2     tt5027774  Tre manifesti a Ebbing, Missouri
# 3             3     tt4925292                         Lady Bird
# 4             4     tt4555426                    L'ora più buia
# ..          ...           ...                               ...
# 561         550    tt10272386                        The Father
# 562         551     tt9784798       Judas and the Black Messiah
# 563         552     tt9770150                         Nomadland
# 564         553     tt1070874        The Trial of the Chicago 7
# 565         554    tt10618286                              Mank
#
#                         title_pt  year  avg_vote     votes  metascore  \
# 0     The Post: A Guerra Secreta  2017       7.2  130017.0        8.3
# ...

# %%
oscar_model_final[oscar_model_final['year'] >=2015]
# Out:
#      Unnamed: 0 imdb_title_id                                     title  \
# 0             0     tt6294822                                  The Post
# 1             1     tt5776858                          Il filo nascosto
# 2             2     tt5027774          Tre manifesti a Ebbing, Missouri
# 3             3     tt4925292                                 Lady Bird
# 4             4     tt4555426                            L'ora più buia
# 5             5     tt5580390  La forma dell'acqua - The Shape of Water
# 6             6     tt5013056                                   Dunkirk
# 7             7     tt5052448                          Scappa - Get Out
# 8             8     tt5726616                     Chiamami col tuo nome
# 9             9     tt2671706                                  Barriere
# 10           10     tt4846340                     Il diritto di contare
# 11           11     tt3741834               Lion - La strada verso casa
# ...

# %%
rotten_2021 = pd.read_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/data/rotten.csv')

# %%
rotten_2021
# Out:
#   imdb_title_id  rotten_tomatoes
# 0    tt10633456              9.8
# 1     tt9620292              9.1
# 2     tt5363618              9.7
# 3    tt10272386              9.8
# 4     tt9784798              9.6
# 5     tt9770150              9.4
# 6     tt1070874              8.9
# 7    tt10618286              8.3

# %%
oscar_model_add_rotten = oscar_model_final.loc[oscar_model_final['year'] == 2020]
oscar_model_add_rotten
# Out:
#                Unnamed: 0                        title  \
# imdb_title_id
# tt10633456            547                       Minari
# tt9620292             548        Promising Young Woman
# tt5363618             549               Sound of Metal
# tt10272386            550                   The Father
# tt9784798             551  Judas and the Black Messiah
# tt9770150             552                    Nomadland
# tt1070874             553   The Trial of the Chicago 7
# tt10618286            554                         Mank
#
#                               title_pt  year  avg_vote     votes  metascore  \
# imdb_title_id
# tt10633456                      Minari  2020       8.0     167.0        8.8
# tt9620292                Bela Vingança  2020       6.5     349.0        7.4
# tt5363618            O Som do Silêncio  2020       6.9     307.0        8.7
# tt10272386                     Meu Pai  2020       8.2     148.0        8.7
# ...

# %%
oscar_model_rotten = oscar_model_add_rotten.drop(columns=['rotten_tomatoes'])

# %%
oscar_model_rotten = pd.merge(left=oscar_model_rotten, right=rotten_2021, how='left', left_on='imdb_title_id', right_on='imdb_title_id')
oscar_model_rotten
# Out:
#   imdb_title_id  Unnamed: 0                        title  \
# 0    tt10633456         547                       Minari
# 1     tt9620292         548        Promising Young Woman
# 2     tt5363618         549               Sound of Metal
# 3    tt10272386         550                   The Father
# 4     tt9784798         551  Judas and the Black Messiah
# 5     tt9770150         552                    Nomadland
# 6     tt1070874         553   The Trial of the Chicago 7
# 7    tt10618286         554                         Mank
#
#                   title_pt  year  avg_vote     votes  metascore  runtime  \
# 0                   Minari  2020       8.0     167.0        8.8    115.0
# 1            Bela Vingança  2020       6.5     349.0        7.4    113.0
# 2        O Som do Silêncio  2020       6.9     307.0        8.7    130.0
# 3                  Meu Pai  2020       8.2     148.0        8.7     97.0
# 4  Judas e o Messias Negro  2020       7.6   37135.0        8.5    126.0
# ...

# %%
df = oscar_model_final.drop(oscar_model_final[(oscar_model_final.year ==2020)].index)

# %%
df
# Out:
#      Unnamed: 0 imdb_title_id                             title  \
# 0             0     tt6294822                          The Post
# 1             1     tt5776858                  Il filo nascosto
# 2             2     tt5027774  Tre manifesti a Ebbing, Missouri
# 3             3     tt4925292                         Lady Bird
# 4             4     tt4555426                    L'ora più buia
# ..          ...           ...                               ...
# 553         542     tt3281548                     Piccole donne
# 554         543     tt7653254           Storia di un matrimonio
# 555         544     tt8579674                              1917
# 556         545     tt7131622    C'era una volta a... Hollywood
# 557         546     tt6751668                          Parasite
#
#                         title_pt  year  avg_vote     votes  metascore  \
# 0     The Post: A Guerra Secreta  2017       7.2  130017.0        8.3
# ...

# %%
oscar_model_final = df.append(oscar_model_rotten, ignore_index=True)

# %%
oscar_model_final
# Out:
#      Unnamed: 0 imdb_title_id                             title  \
# 0             0     tt6294822                          The Post
# 1             1     tt5776858                  Il filo nascosto
# 2             2     tt5027774  Tre manifesti a Ebbing, Missouri
# 3             3     tt4925292                         Lady Bird
# 4             4     tt4555426                    L'ora più buia
# ..          ...           ...                               ...
# 561         550    tt10272386                        The Father
# 562         551     tt9784798       Judas and the Black Messiah
# 563         552     tt9770150                         Nomadland
# 564         553     tt1070874        The Trial of the Chicago 7
# 565         554    tt10618286                              Mank
#
#                         title_pt  year  avg_vote     votes  metascore  \
# 0     The Post: A Guerra Secreta  2017       7.2  130017.0        8.3
# ...

# %%
oscar_model_final.isnull().sum()
# Out:
# Unnamed: 0                    0
# imdb_title_id                 0
# title                         0
# title_pt                      0
# year                          0
# avg_vote                      0
# votes                         0
# metascore                     0
# runtime                       0
# genre                         0
# director                      0
# actors                        0
# writer                        0
# budget                        0
# usa_gross_income              0
# worlwide_gross_income         0
# description                   0
# win                           0
# Won Golden Globe              0
# Won Bafta                     0
# Oscar Nominations             0
# Golden Globe Nominations      0
# Bafta Nominations             0
# Won Directors                 0
# Won Actors                    0
# rotten_tomatoes             174
# dtype: int64

# %%
oscar_model_final.fillna('0',inplace = True)

# %%
oscar_model_final.isnull().sum()
# Out:
# Unnamed: 0                  0
# imdb_title_id               0
# title                       0
# title_pt                    0
# year                        0
# avg_vote                    0
# votes                       0
# metascore                   0
# runtime                     0
# genre                       0
# director                    0
# actors                      0
# writer                      0
# budget                      0
# usa_gross_income            0
# worlwide_gross_income       0
# description                 0
# win                         0
# Won Golden Globe            0
# Won Bafta                   0
# Oscar Nominations           0
# Golden Globe Nominations    0
# Bafta Nominations           0
# Won Directors               0
# Won Actors                  0
# rotten_tomatoes             0
# dtype: int64

# %%
oscar_model_final.to_csv('C:/Users/gisiq/Documents/Cursos/Ironhack/projeto_final/oscar_model_final.csv')
